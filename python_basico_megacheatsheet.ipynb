# %% [markdown]
# # 🐍 Python Básico – Mega Cheatsheet con Ejemplos Ejecutables
# Guía completa para dominar tu prueba.

# %% [markdown]
# ## 1. Variables y Tipos de Datos

# %%
x = 10
y = 3.14
nombre = "Ana"
activo = True
x, y, nombre, activo
# Out:
# (10, 3.14, 'Ana', True)

# %% [markdown]
# ### Conversión de tipos

# %%
int("5"), float("3.2"), str(10), bool(1)
# Out:
# (5, 3.2, '10', True)

# %% [markdown]
# ## 2. Operadores

# %%
a = 10; b = 3
{
 "suma": a+b,
 "resta": a-b,
 "producto": a*b,
 "division": a/b,
 "division_entera": a//b,
 "modulo": a%b,
 "potencia": a**b,
 "comparacion": a>b
}
# Out:
# {'suma': 13,
#  'resta': 7,
#  'producto': 30,
#  'division': 3.3333333333333335,
#  'division_entera': 3,
#  'modulo': 1,
#  'potencia': 1000,
#  'comparacion': True}

# %% [markdown]
# ## 3. Estructuras de Control

# %%
edad = 17
if edad >= 18:
    print("Mayor de edad")
else:
    print("Menor")
# Out:
# Menor

# %% [markdown]
# ## 4. Bucles for y while

# %%
for i in range(1,6):
    print("For →", i)
# Out:
# For → 1
# For → 2
# For → 3
# For → 4
# For → 5

# %%
i=1
while i<=5:
    print("While →", i)
    i+=1
# Out:
# While → 1
# While → 2
# While → 3
# While → 4
# While → 5

# %% [markdown]
# ## 5. Listas

# %%
nums = [10,20,30]
nums.append(40)
nums.remove(20)
nums
# Out:
# [10, 30, 40]

# %% [markdown]
# ## 6. Tuplas

# %%
t = (1,2,3)
t
# Out:
# (1, 2, 3)

# %% [markdown]
# ## 7. Diccionarios

# %%
persona = {"nombre":"Ana","edad":20}
persona["edad"]=21
persona
# Out:
# {'nombre': 'Ana', 'edad': 21}

# %% [markdown]
# ## 8. Funciones

# %%
def saludar(nombre):
    return f"Hola {nombre}"

saludar("Carlos")
# Out:
# 'Hola Carlos'

# %% [markdown]
# ## 9. Manejo de Cadenas

# %%
s = "Hola Mundo"
s.lower(), s.upper(), s.split(), s.replace("Mundo","Python")
# Out:
# ('hola mundo', 'HOLA MUNDO', ['Hola', 'Mundo'], 'Hola Python')

# %% [markdown]
# ## 10. List Comprehension

# %%
[x*2 for x in range(5)]
# Out:
# [0, 2, 4, 6, 8]

# %% [markdown]
# ## 11. Slicing en Listas y Strings

# %%
lista = [0,1,2,3,4,5]
lista[1:4], lista[::-1]
# Out:
# ([1, 2, 3], [5, 4, 3, 2, 1, 0])

# %% [markdown]
# ## 12. Ejercicios Clave Resueltos

# %% [markdown]
# ### Ejercicio 1: Par o Impar

# %%
n = 7
"Par" if n%2==0 else "Impar"
# Out:
# 'Impar'

# %% [markdown]
# ### Ejercicio 2: Mayor de tres números

# %%
a,b,c = 10,25,17
max(a,b,c)
# Out:
# 25

# %% [markdown]
# ### Ejercicio 3: Suma de elementos de una lista

# %%
def suma(lista):
    return sum(lista)

suma([1,2,3,4])
# Out:
# 10

# %% [markdown]
# ### Ejercicio 4: Contar vocales

# %%
def contar_vocales(texto):
    vocales = "aeiou"
    return sum(1 for letra in texto.lower() if letra in vocales)

contar_vocales("Programacion")
# Out:
# 5
