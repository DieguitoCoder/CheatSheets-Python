# %% [markdown]
# # SENA Prep Pack — Contenido Completo
#
# ---
#
# # 1️⃣ Prueba Mock — 30 Preguntas
#
# ## Python (10)
# 1. ¿Qué imprime este código?
# ```python
# x = 5
# y = "5"
# print(x == y)
# ```
#
# 2. Estructura para repetir mientras la condición sea verdadera:
# - while
#
# 3. ¿Qué falta para validar input?
# - try/except
#
# 4. Condición:
# ```python
# if numero > 10 and numero < 50:
#     ...
# ```
#
# 5. Resultado:
# ```python
# def f(a,b): return a + b * 2
# f(2,3) # 8
# ```
#
# 6. Tipo: lista de diccionarios.
#
# 7. Output:
# ```
# 0
# 1
# 2
# ```
#
# 8. Método para eliminar: remove() o pop().
#
# 9. Ejemplo:
# ```python
# def suma(a,b): return a+b
# ```
#
# 10. Error: clave "apellido" no existe.
#
# ---
#
# ## Lógica (5)
# 11. Orden correcto: 2,4,3,1
# 12. Un algoritmo es un conjunto de pasos lógicos.
# 13. Resultado: True
# 14. Pseudocódigo:
# ```
# Pedir nombre
# Si longitud > 5 → Mostrar "Largo"
# Sino → "Corto"
# ```
# 15. Error: pedir número debe ir antes de sumar.
#
# ---
#
# ## HTML/CSS (5)
# 16. Etiqueta de enlace: `<a>`
# 17. class asigna estilos CSS.
# 18. Selector: `#main`
# 19. Corrección:
# ```html
# <h1>Hola</h1>
# <p>Bienvenido</p>
# ```
# 20. padding.
#
# ---
#
# ## SQL (8)
# 21. Selecciona nombres de mayores de 18.
# 22. INSERT:
# ```sql
# INSERT INTO estudiantes(nombre, edad) VALUES ("Ana",20);
# ```
#
# 23. PRIMARY KEY → identificador único.
# 24. JOIN correcto: INNER
# 25. DELETE elimina registro.
# 26. Falta PRIMARY KEY.
# 27. JOIN ejemplo:
# ```sql
# SELECT e.nombre, c.nombre
# FROM estudiantes e
# JOIN cursos c ON e.curso_id = c.id;
# ```
#
# 28. UPDATE correcto:
# ```sql
# UPDATE estudiantes SET edad=20 WHERE id=1;
# ```
#
# ---
#
# ## JavaScript (2)
# 29. "22"
# 30. let = variable; const = no cambia.
#
# ---
#
# # 2️⃣ Mini Proyecto Python + SQL
#
# ## Python — Sistema de Inventario
#
# ```python
# # INVENTORY SYSTEM
#
# products = []
#
# def add_product():
#     try:
#         pid = int(input("ID: "))
#         name = input("Name: ").strip()
#         price = float(input("Price: "))
#         products.append({"id": pid, "name": name, "price": price})
#     except:
#         print("Invalid input.")
#
# def list_products():
#     for p in products:
#         print(p)
#
# def find_product():
#     pid = int(input("ID to search: "))
#     for p in products:
#         if p["id"] == pid:
#             print(p)
#             return
#     print("Not found.")
#
# def delete_product():
#     pid = int(input("ID to delete: "))
#     for p in products:
#         if p["id"] == pid:
#             products.remove(p)
#             print("Deleted.")
#             return
#     print("Not found.")
#
# def menu():
#     while True:
#         print("\n1 Add\n2 List\n3 Search\n4 Delete\n0 Exit")
#         op = input("Option: ")
#         if op=="1": add_product()
#         elif op=="2": list_products()
#         elif op=="3": find_product()
#         elif op=="4": delete_product()
#         elif op=="0": break
#
# menu()
# ```
#
# ---
#
# ## SQL — Base de Datos
#
# ```sql
# CREATE TABLE productos(
#     id INT PRIMARY KEY,
#     nombre VARCHAR(50),
#     precio DECIMAL(10,2)
# );
#
# INSERT INTO productos VALUES
# (1,"Mouse",40.00),
# (2,"Teclado",60.00),
# (3,"Monitor",300.00);
#
# SELECT * FROM productos;
# SELECT * FROM productos WHERE precio > 50;
# UPDATE productos SET precio = 320 WHERE id = 3;
# DELETE FROM productos WHERE id = 1;
# SELECT * FROM productos ORDER BY precio DESC;
# ```
#
# ---
#
# # 3️⃣ Resumen Express — Lo que debes estudiar hoy
#
# ## Python
# - if / elif / else
# - while + validación
# - for + range
# - funciones
# - listas (append, remove, pop)
# - diccionarios
# - try/except
# - input seguro
#
# ## SQL
# - SELECT, INSERT, UPDATE, DELETE
# - WHERE
# - ORDER BY
# - INNER JOIN básico
# - PRIMARY KEY
#
# ## HTML/CSS
# - `<html>`, `<head>`, `<body>`
# - `<a href="">`
# - `<img>`
# - IDs y clases
# - padding, margin
#
# ## JavaScript
# - let, const
# - console.log
# - concatenación
